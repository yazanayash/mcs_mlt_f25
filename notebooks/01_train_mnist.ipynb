# %% [markdown]
# # Handwritten Digit Recognition - MNIST
#
# This notebook is used for exploring the dataset and producing figures for the report.
# The reusable code lives in the `ml/` package.
#
# ## Step 1 - Data exploration

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('Train images:', x_train.shape)
print('Train labels:', y_train.shape)
print('Test images: ', x_test.shape)
print('Test labels: ', y_test.shape)
print('Pixel values range from', x_train.min(), 'to', x_train.max())

# %% [markdown]
# ### Sample digits
# Let's look at a few images so we know what the model is working with.

# %%
plt.figure(figsize=(8, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title('Label: %d' % y_train[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Class distribution
# Checking that the dataset is reasonably balanced across the 10 digits.

# %%
digits, counts = np.unique(y_train, return_counts=True)

plt.figure(figsize=(8, 4))
plt.bar(digits, counts)
plt.xticks(digits)
plt.xlabel('Digit')
plt.ylabel('Number of training samples')
plt.title('MNIST training set class distribution')
plt.show()

for d, c in zip(digits, counts):
    print('Digit %d: %d samples' % (d, c))
